# %% [markdown]
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# import sklearn
# from sklearn.decomposition import TruncatedSVD

# %%
HM = pd.read_csv("C:/Users/user/Desktop/MA336/H&M.csv")
HM.shape
# Out:
# (105542, 25)

# %%
HM.isnull().sum()
# Out:
# article_id                        0
# product_code                      0
# prod_name                         0
# product_type_no                   0
# product_type_name                 0
# product_group_name                0
# graphical_appearance_no           0
# graphical_appearance_name         0
# colour_group_code                 0
# colour_group_name                 0
# perceived_colour_value_id         0
# perceived_colour_value_name       0
# perceived_colour_master_id        0
# perceived_colour_master_name      0
# department_no                     0
# department_name                   0
# index_code                        0
# index_name                        0
# index_group_no                    0
# index_group_name                  0
# section_no                        0
# section_name                      0
# garment_group_no                  0
# garment_group_name                0
# detail_desc                     416
# dtype: int64

# %%
HM.dropna()
# Out:
#         article_id  product_code               prod_name  product_type_no  \
# 0        108775015        108775               Strap top              253
# 1        108775044        108775               Strap top              253
# 2        108775051        108775           Strap top (1)              253
# 3        110065001        110065       OP T-shirt (Idro)              306
# 4        110065002        110065       OP T-shirt (Idro)              306
# ...            ...           ...                     ...              ...
# 105537   953450001        953450  5pk regular Placement1              302
# 105538   953763001        953763       SPORT Malaga tank              253
# 105539   956217002        956217         Cartwheel dress              265
# 105540   957375001        957375        CLAIRE HAIR CLAW               72
# 105541   959461001        959461            Lounge dress              265
#
#        product_type_name  product_group_name  graphical_appearance_no  \
# ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.neighbors import NearestNeighbors
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score

# %%
data= HM[["product_code", "detail_desc"]]
data.head()
# Out:
#    product_code                                        detail_desc
# 0        108775            Jersey top with narrow shoulder straps.
# 1        108775            Jersey top with narrow shoulder straps.
# 2        108775            Jersey top with narrow shoulder straps.
# 3        110065  Microfibre T-shirt bra with underwired, moulde...
# 4        110065  Microfibre T-shirt bra with underwired, moulde...

# %%
product_descriptions = data.head(500)
product_descriptions["detail_desc"].head(10)
# Out:
# 0              Jersey top with narrow shoulder straps.
# 1              Jersey top with narrow shoulder straps.
# 2              Jersey top with narrow shoulder straps.
# 3    Microfibre T-shirt bra with underwired, moulde...
# 4    Microfibre T-shirt bra with underwired, moulde...
# 5    Microfibre T-shirt bra with underwired, moulde...
# 6    Semi shiny nylon stockings with a wide, reinfo...
# 7    Semi shiny nylon stockings with a wide, reinfo...
# 8    Tights with built-in support to lift the botto...
# 9    Semi shiny tights that shape the tummy, thighs...
# Name: detail_desc, dtype: object

# %%
vectorizer = TfidfVectorizer(stop_words='english')
X1 = vectorizer.fit_transform(product_descriptions["detail_desc"])
X1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22540/2957102026.py in <module>
# ----> 1 vectorizer = TfidfVectorizer(stop_words='english')
#       2 X1 = vectorizer.fit_transform(product_descriptions["detail_desc"])
#       3 X1
#
# NameError: name 'TfidfVectorizer' is not defined

# %%
X=X1

kmeans = KMeans(n_clusters = 10, init = 'k-means++')
y_kmeans = kmeans.fit_predict(X)
plt.plot(y_kmeans, ".")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22540/366908723.py in <module>
# ----> 1 X=X1
#       2
#       3 kmeans = KMeans(n_clusters = 10, init = 'k-means++')
#       4 y_kmeans = kmeans.fit_predict(X)
#       5 plt.plot(y_kmeans, ".")
#
# NameError: name 'X1' is not defined

# %%
def print_cluster(i):
    print("Cluster %d:" % i),
    for ind in order_centroids[i, :10]:
        print(' %s' % terms[ind]),
    print

# %%
true_k = 10

model = KMeans(n_clusters=true_k, init='k-means++', max_iter=100, n_init=1)
model.fit(X1)

print("Top terms per cluster:")
order_centroids = model.cluster_centers_.argsort()[:, ::-1]
terms = vectorizer.get_feature_names()
for i in range(true_k):
    print_cluster(i)
# Out:
# Top terms per cluster:
# Cluster 0:
#  denier
#  tights
#  20
#  elasticated
#  waist
#  matt
#  semi
#  opaque
#  80
#  shape
# Cluster 1:
#  leggings
#  elasticated
#  jersey
#  waist
#  soft
#  sturdy
#  cotton
#  patterned
#  extra
#  organic
# Cluster 2:
#  growing
#  extra
#  tummy
#  space
#  tights
#  denier
#  matt
#  room
#  200
#  opaque
# Cluster 3:
#  cups
#  adjustable
#  support
#  straps
#  shoulder
#  padded
#  swimsuit
#  gathers
#  panels
#  sculpting
# Cluster 4:
#  sweatshirt
#  fabric
#  hem
#  zip
#  jacket
#  cuffs
#  pockets
#  hood
#  drawstring
#  ribbing
# Cluster 5:
#  seam
#  dress
#  narrow
#  straps
#  shoulder
#  unlined
#  sleeveless
#  long
#  jersey
#  elasticated
# Cluster 6:
#  pockets
#  washed
#  fit
#  denim
#  legs
#  jeans
#  regular
#  tapered
#  stretch
#  fake
# Cluster 7:
#  hair
#  cm
#  metal
#  width
#  elastics
#  plastic
#  claws
#  clips
#  belt
#  buckle
# Cluster 8:
#  cotton
#  short
#  jersey
#  soft
#  sleeved
#  pyjamas
# ...

# %%
def show_recommendations(product):
    #print("Cluster ID:")
    Y = vectorizer.transform([product])
    prediction = model.predict(Y)
    #print(prediction)
    print_cluster(prediction[0])

# %%
show_recommendations("provide warmth")
# Out:
# Cluster 9:
#  elastics
#  hair
#  support
#  cups
#  adjustable
#  straps
#  metal
#  padded
#  shoulder
#  bum

# %%
show_recommendations("comfy")
# Out:
# Cluster 9:
#  elastics
#  hair
#  support
#  cups
#  adjustable
#  straps
#  metal
#  padded
#  shoulder
#  bum
